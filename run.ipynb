# %%
from utils import run, decode, from_pretrained
from model import GPT_conf, GPTModel
import torch
from pprint import pprint as pp
import matplotlib.pyplot as plt
import numpy as np

# %%
conf = GPT_conf()
model, L = run(conf)
# Out:
# Number of T = 211,327
#
#
# Number of P=53,147
# Loading pre-trained Model 	 L==2.1745896339416504
# 0it [00:04, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 conf = GPT_conf()
# ----> 2 model, L = run(conf)
#
# File ~/AI/XAI/repos/GPT/utils.py:121, in run(conf)
#     118 for e in range(epochs):
#     120     for b , (X, Y) in tqdm(enumerate(load_batch(TRAIN, batches=batches))):
# --> 121         eval_and_logging(b, model, optimizer, TRAIN, EVAL)
#     122         Z, loss = model(X, Y)
#     124         optimizer.zero_grad()
#
# File ~/AI/XAI/repos/GPT/utils.py:102, in eval_and_logging(n_batch, model, optimizer, TRAIN, EVAL, cut)
#     100 def eval_and_logging(n_batch, model, optimizer, TRAIN, EVAL, cut=1_000):
#     101     if n_batch % cut == 0 or n_batch == 23_774:
# --> 102         e_loss, o_loss = evaluate(model, TRAIN, EVAL)
# ...

# %%
L.extend([0] * 8)
lz = torch.tensor(L)
lz = lz.view(200, -1)
lz = lz.mean(dim=-1)
plt.plot(lz);

# %%
model.eval()

p = torch.zeros((1, 1), dtype=torch.long)
for _ in range(10):
    result = model.create(p, max_new_tokens=32)
    c = ''.join(decode(list(result.squeeze(0).numpy())))
    pp(c.split('\n'))
# Out:
# ['antelea', 'derieysha']
# ['', 'harameleahokesty']
# ['', 'amaqtaloneiryala']
# ['yitha', 'ifyovy', 'onah']
# ['leveiahzarindikon']
# ['h', 'yoeoh', 'nardausee']
# ['elthita', 'keleita', 'a']
# ['iyalidja', 'lyahagid']
# ['riahirwelilyeimag']
# ['odurrgariesanieie']
